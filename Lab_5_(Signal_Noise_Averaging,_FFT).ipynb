# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahkhan57721/Advanced-Physics-Lab/blob/main/Lab_5_(Signal_Noise_Averaging%2C_FFT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path1 = "/content/drive/MyDrive/Colab Notebooks/Advanced Lab 1/Lab 5/Lab 5 - 1.csv"
data1 = np.genfromtxt(path1, delimiter=',', names=True)

path2= "/content/drive/MyDrive/Colab Notebooks/Advanced Lab 1/Lab 5/Lab 5 - 5.csv"
data2 = np.genfromtxt(path2, delimiter=',', names=True)

path3= "/content/drive/MyDrive/Colab Notebooks/Advanced Lab 1/Lab 5/Lab 5 - 10.csv"
data3 = np.genfromtxt(path3, delimiter=',', names=True)

# %%
time = data1["time"]
sin1 = data1["signal"]
sin2 = data2["signal"]
sin3 = data3["signal"]

# %%
fig, ax = plt.subplots(figsize=(6,3), dpi=150)

ax.plot(time, sin3, color='orange', label="Running average of 10")
ax.plot(time, sin2, color='red', label="Running average of 5")
ax.plot(time, sin1, color='steelblue', label="Running average of 1")

ax.set_xlabel('Time')
ax.set_ylabel('Value')
ax.set_title('Three Data sets')
ax.grid()
plt.legend()
plt.xlim([6000,9500])
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(time, voltage, label="thermistor")

ax.set_xlabel('Time [minutes]')
ax.set_ylabel('Temprature Measured by Thermistor [K]')
ax.set_title('Signal as a function of time')

ax.grid()
plt.show()

# %%
from scipy.fft import fft, fftfreq
from scipy.fft import rfft, rfftfreq

# %%
N = len(voltage)
sample_rate = 1000

yf = fft(voltage)
xf = fftfreq(N, 1 / sample_rate)
fig, ax = plt.subplots()
ax.plot(xf, np.abs(yf),color='blue')
ax.set_xlabel('Frequency (Hz)')
ax.set_ylabel('Signal')
ax.set_title('Signal FFT Spectrum')
ax.set_xlim(0,10)
ax.set_ylim(0,1e6)
ax.grid()
plt.show()

# %%
from scipy.signal import find_peaks

# %%
peaks, _ = find_peaks(np.abs(yf), height=0.3e6)
print('First peak is at: '+str(peaks[0]) )
print('which corresponds to a frequency of '+str( xf[peaks[0]] )+' Hz')

print('First peak is at: '+str(peaks[1]) )
print('which corresponds to a frequency of '+str( xf[peaks[1]] )+' Hz')

print('First peak is at: '+str(peaks[2]) )
print('which corresponds to a frequency of '+str( xf[peaks[2]] )+' Hz')

print('First peak is at: '+str(peaks[3]) )
print('which corresponds to a frequency of '+str( xf[peaks[3]] )+' Hz')
# Out:
# First peak is at: 32
# which corresponds to a frequency of 1.5848645436085385 Hz
# First peak is at: 65
# which corresponds to a frequency of 3.2192561042048435 Hz
# First peak is at: 117
# which corresponds to a frequency of 5.794660987568719 Hz
# First peak is at: 147
# which corresponds to a frequency of 7.280471497201724 Hz
